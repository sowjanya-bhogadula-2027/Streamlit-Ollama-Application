# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2']="true"
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000021BDA8AC190> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000021BDA8AC550> root_client=<openai.OpenAI object at 0x0000021BDA68FED0> root_async_client=<openai.AsyncOpenAI object at 0x0000021BDA8AC2D0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
#input and get response

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a class of artificial intelligence systems designed to generate new content, such as text, images, music, or other forms of data, often resembling human-created content. This type of AI leverages advanced models, including neural networks like Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and Transformer models, to produce high-quality, original outputs.\n\nGenerative AI works by learning patterns and structures from existing data and then using what it has learned to create new, similar content. These systems can perform a wide array of tasks, such as creating realistic images, composing music, writing creative text, and even generating synthetic data for various purposes.\n\nThe applications of generative AI are vast and include areas like art and entertainment, design, content creation, virtual reality, and even scientific research. However, the technology also poses challenges and ethical considerations, such as issues related to intellectual property, authenticity, and potential misuse for generating misleading information or deepfakes.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 201, 'prompt_tokens': 13, 'total_tokens': 214, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_01561ae8d3', 'id': 'chatcmpl-DHyfciNqpjBTaD0KZRJUDLRiRk6gO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019cd998-52bb-7630-b52e-4680dc157627-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 201, 'total_tokens': 214, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
#chat prompt template 

from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","you are an expert AI Engineer. Provide me answers based on the question"),
        ("user","{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an expert AI Engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a comprehensive suite of tools and services designed to streamline the development, deployment, and monitoring of applications using large language models (LLMs). It builds upon the concept of Langchain, which is a framework for linking different language processing components and models in a cohesive manner.\n\nKey features of Langsmith include:\n\n1. **Experimentation Platform**: Enables developers to experiment with various models and configurations to optimize the performance of their applications.\n\n2. **Monitoring and Evaluation**: Provides tools to track the performance of language models in real-time, helping identify areas for improvement and ensure consistent application behavior.\n\n3. **Integration Support**: Facilitates the integration of LLMs with existing applications and infrastructures, making it easier to adopt these technologies in production environments.\n\n4. **Robust Development Tools**: Offers a set of intuitive tools for developers to design, build, and test language model-powered applications efficiently.\n\nBy focusing on these aspects, Langsmith aims to make it easier for businesses and developers to leverage the capabilities of large language models, from prototype to production, ensuring reliability and scalability.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 218, 'prompt_tokens': 33, 'total_tokens': 251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_01561ae8d3', 'id': 'chatcmpl-DHyp9H5F88CNM1gaewtE2T0Bwcalg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019cd9a1-50ce-7b32-9ff9-dbf1e7eac3e3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 218, 'total_tokens': 251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
#string output parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a tool developed to enhance and streamline the development of applications using language models. It offers advanced features for observing, evaluating, and optimizing interactions with language models, especially during the deployment phase of applications built with LangChain. Langsmith allows developers to deeply analyze the performance of language models, providing insights through detailed tracing, debugging, and evaluation capabilities. This helps in refining model usage, improving prompt engineering, and ensuring that apps perform as expected in real-world scenarios. Langsmith effectively supports the iterative process of improving language model-based applications, making it easier for developers to manage complexity and optimize outcomes.
